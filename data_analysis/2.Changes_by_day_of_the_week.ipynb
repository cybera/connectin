# %%
from IPython.display import display, Math, Latex, HTML
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }
  
  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# ## Ping latency, Upload/Download speeds  by day of the week

# %%
#Load libraries:
from data_exploration import *
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#Set up test time interval:
time_interval='2w' #5d
print("Time interval: ", time_interval)
# Out:
# Time interval:  2w

# %%
#Set up influxdb connection:
client, client_df = connect_to_influxdb()

# %% [markdown]
# ### We will use 2 approaches:
# #### By day of the week
# We will find mean, max and median ping latency/upload/download speed for all devices grouped by day of the week.
# #### By time group
# We will find mean, max and median ping latency/upload/download speed for all devices grouped by :
#  - **group1** Weekday: Mon, Tue, Wed, Thur, Fri
#  - **group2** Weekend: Sut, Sun

# %% [markdown]
# ## Ping Latency

# %% [markdown]
# ### Data coming from collectd

# %%
device_numbers=get_tag_values_influxdb(client_influx=client,table_name='PING', tag_name='SK_PI')
device_numbers=list(map(int, device_numbers))
device_numbers= sorted(device_numbers)
#print(device_numbers)

# %%
ping_mean_query="SELECT MAX(PING),MEAN(PING), MEDIAN(PING) FROM PING WHERE PING!=0 AND time >= now()-"+\
                time_interval+" GROUP BY time(1h), SK_PI;"

# %%
ping_hourly_dataframe=get_3_stats_influxdb(client_influx=client,
                                           query_influx=ping_mean_query,
                                           stat_name1='max',
                                           stat_name2='mean',
                                           stat_name3='median',
                                           device_numbers=device_numbers)

# %%
#To check:
#ping_hourly_dataframe[ping_hourly_dataframe["SK_PI"]==3]
#q="SELECT MAX(PING), MEAN(PING), MEDIAN(PING) FROM PING WHERE PING!=0 AND time >= now()-4w AND SK_PI='3' GROUP BY time(1h);"
#ping_df = get_dataframe_from_influxdb(client_df=client_df,query_influx=q,table_name='PING')
#ping_df

# %%
ping_hourly_dataframe["weekday"]=ping_hourly_dataframe["time"].dt.weekday_name
ping_hourly_dataframe["weekday"] = pd.Categorical(ping_hourly_dataframe["weekday"], ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])

# %%
device_number=7
subset=ping_hourly_dataframe[ping_hourly_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='mean',sort_value='weekday',
               title="Ping latency(collectd) by day of the week for the device "+str(device_number)+" over the last "+time_interval, 
               ytitle="Miliseconds",weekdays=True)
# Out:
# <div id="7da46762-04af-4837-be29-8d214ed3c6ba" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7da46762-04af-4837-be29-8d214ed3c6ba", [{"type": "box", "y": [42.985376835236515, 45.919090403337954, 52.2019958391123, 45.42754937413077, 44.95893314763232, 43.72847361111106, 42.706204802259876, 41.97178888888891, 42.71551460361617, 43.17646527777778, 43.02018055555558, 48.38298191933234, 53.93661785216182, 53.757745428973294, 48.600688547486065, 43.47741527777781, 34.76779305555561, 35.04375138888889, 36.61802987197728, 36.04005972222221, 37.35065598885794, 40.68703862660943, 36.10140555555557, 41.08568888888886, 39.89895555555559, 42.20924756606404, 41.06966898470095, 34.71145555555561, 33.959784722222196, 33.739126388888884, 33.08572919605079, 32.749641666666676, 32.827790277777744, 32.83962222222223, 33.05205138888893, 34.54665972222225, 36.68876805555558, 33.90147916666663, 33.75087916666664, 35.68934909596663, 33.84326008344925, 33.828044444444394, 34.30895756718523, 37.400247222222205, 35.67175416666668, null, null, null, null], "name": "Monday", "marker": {"color": "222222"}}, {"type": "box", "y": [38.42983031988875, 38.54769444444443, 35.738494444444456, 36.314963838664795, 37.95405424200274, 35.66664305555558, 33.68203472222218, 33.35383194444447, 32.759379166666655, 32.63693201133139, 33.094520833333306, 32.44157222222223, 32.80388472222224, 33.04330277777776, 34.20666063977745, 39.13577190542422, 34.313927777777764, 34.09994142259413, 34.88057579972188, 35.51404172461753, 38.05989151599442, 39.66169552238803, 37.17963838664809, 39.040388888888884, 36.97493333333331, 37.67484700973573, 40.781498611111104, 105.9921474269819, 111.06433704735352, 94.42213370473546, 41.3853866481224, 34.86166805555555, 34.772402777777785, 33.462970338983034, 33.92978888888887, 34.81972916666662, 34.170525000000005, 42.50170473537604, 41.0605924895689, 37.99215620641564, 35.530424200278176, 37.01082753824759, 36.29691388888893, 38.63150069541031, 38.81361891515995, 57.819817280453215, 39.95846388888892, 37.30212656467317], "name": "Tuesday", "marker": {"color": "F3C300"}}, {"type": "box", "y": [41.69760279720277, 42.62613888888891, 41.254988888888896, 50.5587819444444, 34.844258692628706, 37.12936250000001, 34.94664444444443, 34.20145897079276, 33.93353055555557, 33.4930324858757, 32.89962083333332, 32.87090416666668, 33.2416208333333, 33.01369444444449, 34.71681641168286, 35.53605020920507, 35.52129999999996, 35.00514861111105, 34.97451388888888, 35.50859331476321, 35.13313611111112, 35.44998022598874, 34.99450833333329, 34.79339722222222, 39.73734818941505, 46.116906779661, 36.50725730180805, 39.90903194444442, 61.11110152990267, 39.73119054242006, 33.4440888888889, 33.82871666666666, 32.94261752433939, 32.889011299435055, 32.9597652777778, 33.32345555555555, 33.13289444444445, 32.868569444444454, 33.253566063977736, 35.40455292479109, 34.99536856745478, 34.72568105849583, 35.52422809457583, 34.64695000000006, 34.74352638888891, 34.62979066478078, 38.93292083333327, 36.523083449235095], "name": "Wednesday", "marker": {"color": "875692"}}, {"type": "box", "y": [34.58201944444446, 34.506325905292464, 36.01885952712103, 36.012724617524384, 36.7241196105702, 39.54865555555555, 34.52500138888887, 32.72952083333335, 32.494731944444396, 32.715668547249614, 32.885912499999975, 33.04480277777775, 32.86111388888885, 33.138458333333325, 35.086118055555524, 34.24525138888888, 34.72790694444445, 34.267472222222224, 35.69458995815897, 34.97198885793875, 34.64435883171069, 34.72336864406783, 34.82243611111114, 38.90001527777775, 35.09698194444442, 36.983886111111126, 42.942698191933246, 38.8447093184979, 39.840336578581365, 35.93227361111112, 33.63397361111108, 33.80958611111112, 33.18839305555558, 33.18171468926555, 32.739220833333334, 32.74393333333335, 32.82594305555 ...

# %%
by_weekday_by_device_p1=mean_max_median_by2(input_dataframe=ping_hourly_dataframe,value1="mean", value2="max",
                                          value3="median",group_by_value="weekday")

# %%
device_number=7
subset=by_weekday_by_device_p1[by_weekday_by_device_p1["SK_PI"]==device_number]
combined_bar_plot_3traces(xvalues=subset["weekday"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(collectd) by day of the week for the device "+str(device_number)+" over the last "+time_interval,
                         xtitle="weekday",
                         stack=False)
# Out:
# <div id="0b3d6524-e2b5-472e-8b7a-5269b6425b8a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0b3d6524-e2b5-472e-8b7a-5269b6425b8a", [{"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [870.874, 863.592, 753.104, 699.807, 884.499, 552.348, 667.97], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [39.4318648373019, 41.03729555711791, 36.46305642103215, 35.30723909648038, 39.91392703369251, 35.46917077910983, 36.258114516210206], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [34.2255, 34.052, 33.36, 33.311749999999996, 33.57875, 33.07675, 33.2235], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(collectd) by day of the week for the device 7 over the last 2w", "xaxis": {"title": "weekday"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
weekday="Sunday"
subset=by_weekday_by_device_p1[by_weekday_by_device_p1["weekday"]==weekday]
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(collectd) by day of the week for the day "+str(weekday)+" over the last "+time_interval,
                         stack=False)
# Out:
# <div id="5369cd20-a36a-4ca1-85ef-8601c4de7341" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5369cd20-a36a-4ca1-85ef-8601c4de7341", [{"type": "bar", "x": [3, 7, 8, 9, 11, 12, 15, 16, 17, 18], "y": [37.98, 667.97, 86.235, 91.17, 41.677, 330.231, 45.116, 894.437, null, null], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 7, 8, 9, 11, 12, 15, 16, 17, 18], "y": [14.770370271817853, 36.258114516210206, 29.410464390888194, 34.63129768902592, 27.718761314906754, 25.280740985570983, 35.007372743055555, 39.65311764345049, null, null], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 7, 8, 9, 11, 12, 15, 16, 17, 18], "y": [14.7305, 33.2235, 29.37225, 32.51625, 27.57775, 24.287, 35.01475000000001, 37.76925, null, null], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(collectd) by day of the week for the day Sunday over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
pd.options.mode.chained_assignment = None
ping_hourly_dataframe["day_group"]="Weekday"
ping_hourly_dataframe.loc[(ping_hourly_dataframe["weekday"]=="Sunday")|(ping_hourly_dataframe["weekday"]=="Saturday"),"day_group"]="Weekend"

# %%
device_number=7
subset=ping_hourly_dataframe[ping_hourly_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='mean',sort_value='day_group',
               title="Ping latency(collectd) by day group for the device "+str(device_number)+" over the last "+time_interval,
               ytitle="Miliseconds")
# Out:
# <div id="03dbf1e9-8970-41ff-be67-fd20a0213fe8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("03dbf1e9-8970-41ff-be67-fd20a0213fe8", [{"type": "box", "y": [42.985376835236515, 45.919090403337954, 52.2019958391123, 45.42754937413077, 44.95893314763232, 43.72847361111106, 42.706204802259876, 41.97178888888891, 42.71551460361617, 43.17646527777778, 43.02018055555558, 48.38298191933234, 53.93661785216182, 53.757745428973294, 48.600688547486065, 43.47741527777781, 34.76779305555561, 35.04375138888889, 36.61802987197728, 36.04005972222221, 37.35065598885794, 38.42983031988875, 38.54769444444443, 35.738494444444456, 36.314963838664795, 37.95405424200274, 35.66664305555558, 33.68203472222218, 33.35383194444447, 32.759379166666655, 32.63693201133139, 33.094520833333306, 32.44157222222223, 32.80388472222224, 33.04330277777776, 34.20666063977745, 39.13577190542422, 34.313927777777764, 34.09994142259413, 34.88057579972188, 35.51404172461753, 38.05989151599442, 39.66169552238803, 37.17963838664809, 39.040388888888884, 41.69760279720277, 42.62613888888891, 41.254988888888896, 50.5587819444444, 34.844258692628706, 37.12936250000001, 34.94664444444443, 34.20145897079276, 33.93353055555557, 33.4930324858757, 32.89962083333332, 32.87090416666668, 33.2416208333333, 33.01369444444449, 34.71681641168286, 35.53605020920507, 35.52129999999996, 35.00514861111105, 34.97451388888888, 35.50859331476321, 35.13313611111112, 35.44998022598874, 34.99450833333329, 34.79339722222222, 34.58201944444446, 34.506325905292464, 36.01885952712103, 36.012724617524384, 36.7241196105702, 39.54865555555555, 34.52500138888887, 32.72952083333335, 32.494731944444396, 32.715668547249614, 32.885912499999975, 33.04480277777775, 32.86111388888885, 33.138458333333325, 35.086118055555524, 34.24525138888888, 34.72790694444445, 34.267472222222224, 35.69458995815897, 34.97198885793875, 34.64435883171069, 34.72336864406783, 34.82243611111114, 38.90001527777775, 36.29021527777776, 35.746601388888905, 35.82581527777782, 36.749490959666204, 41.105522948539615, 35.20879166666668, 34.691616666666675, 33.74317638888894, 33.43896527777774, 33.50137853107346, 32.5585625, 32.43712916666668, 33.983522222222284, 36.54664345403903, 35.50176805555556, 35.12649790794978, 46.83968583450215, 35.15686091794157, 35.14242559109873, 33.817991655076476, 34.42053750000002, 36.8933513513514, 49.69520138888887, 39.373011111111126, 40.68703862660943, 36.10140555555557, 41.08568888888886, 39.89895555555559, 42.20924756606404, 41.06966898470095, 34.71145555555561, 33.959784722222196, 33.739126388888884, 33.08572919605079, 32.749641666666676, 32.827790277777744, 32.83962222222223, 33.05205138888893, 34.54665972222225, 36.68876805555558, 33.90147916666663, 33.75087916666664, 35.68934909596663, 33.84326008344925, 33.828044444444394, 34.30895756718523, 37.400247222222205, 35.67175416666668, 36.97493333333331, 37.67484700973573, 40.781498611111104, 105.9921474269819, 111.06433704735352, 94.42213370473546, 41.3853866481224, 34.86166805555555, 34.772402777777785, 33.462970338983034, 33.92978888888887, 34.81972916666662, 34.170525000000005, 42.50170473537604, 41.0605924895689, 37.99215620641564, 35.530424200278176, 37.01082753824759, 36.29691388888893, 38.63150069541031, 38.81361891515995, 57.819817280453215, 39.95846388888892, 37.30212656467317, 39.73734818941505, 46.116906779661, 36.50725730180805, 39.90903194444442, 61.11110152990267, 39.73119054242006, 33.4440888888889, 33.82871666666666, 32.94261752433939, 32.889011299435055, 32.9597652777778, 33.32345555555555, 33.13289444444445, 32.868569444444454, 33.253566063977736, 35.40455292479109, 34.99536856745478, 34.72568105849583, 35.52422809457583, 34.64695000000006, 34.74352638888891, 34.62979066478078, 38.93292083333327, 36.523083449235095, 35.09698194444442, 36.983886111111126 ...

# %%
by_group_by_device_p1 = mean_max_median_by2(input_dataframe=ping_hourly_dataframe,value1="mean", value2="max",
                                             value3="median",group_by_value="day_group")

# %%
device_number=7
subset=by_group_by_device_p1[by_group_by_device_p1["SK_PI"]==device_number]
combined_bar_plot_3traces(xvalues=subset["day_group"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(collectd) by day group for the device "+str(device_number)+" over the last "+time_interval,
                         xtitle="day_group",
                         stack=False)
# Out:
# <div id="3404ac1d-c2c8-4bcd-822b-ba4116d9125e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3404ac1d-c2c8-4bcd-822b-ba4116d9125e", [{"type": "bar", "x": ["Weekday", "Weekend"], "y": [884.499, 667.97], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [38.41800332016069, 35.86364264766002], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [33.5595, 33.184250000000006], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(collectd) by day group for the device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
day_group="Weekend"
subset=by_group_by_device_p1[by_group_by_device_p1["day_group"]==day_group]
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(collectd) by device for "+day_group+"s over the last "+time_interval,
                         stack=False)
# Out:
# <div id="77da6578-41e9-4e3f-8c21-2e8fede08bf4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("77da6578-41e9-4e3f-8c21-2e8fede08bf4", [{"type": "bar", "x": [3, 7, 8, 9, 11, 12, 15, 16, 17, 18], "y": [66.353, 667.97, 86.235, 103.778, 41.677, 424.264, 45.116, 894.437, null, null], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 7, 8, 9, 11, 12, 15, 16, 17, 18], "y": [14.779097427004972, 35.86364264766002, 29.408701409855833, 33.91487579666642, 27.742265960954896, 25.995715696503595, 35.01111701388889, 40.405752559834994, null, null], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 7, 8, 9, 11, 12, 15, 16, 17, 18], "y": [14.728, 33.184250000000006, 29.36425, 32.4855, 27.5855, 24.319, 35.010000000000005, 37.756, null, null], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(collectd) by device for Weekends over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Data coming from speedtest

# %%
query_ping = "SELECT * FROM SPEEDTEST_PING WHERE PROVIDER!='iperf' AND time >= now()-"+time_interval+" AND PING!=0;"
ping_speedtest_dataframe = get_dataframe_from_influxdb(client_df=client_df,query_influx=query_ping,table_name='SPEEDTEST_PING')

# %%
ping_speedtest_dataframe["weekday"]=ping_speedtest_dataframe["time"].dt.weekday_name
ping_speedtest_dataframe["weekday"] = pd.Categorical(ping_speedtest_dataframe["weekday"], ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])

# %%
device_number=7
subset=ping_speedtest_dataframe[ping_speedtest_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='PING',sort_value='weekday',
               title="Ping latency(speedtest) by day of the week for the device "+str(device_number)+" over the last "+time_interval,
               ytitle="Miliseconds",weekdays=True)
# Out:
# <div id="17fd8a60-c685-4922-9943-b618a6f21933" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("17fd8a60-c685-4922-9943-b618a6f21933", [{"type": "box", "y": [95.855, 82.014, 94.528, 93.295, 83.451, 82.149, 78.783, 80.396, 76.119, 76.493, 88.735, 81.029, 100.152], "name": "Monday", "marker": {"color": "222222"}}, {"type": "box", "y": [79.523, 81.361, 80.353, 78.22, 79.434, 134.032, 82.277, 220.42, 80.875, 76.857, 79.567, 83.735], "name": "Tuesday", "marker": {"color": "F3C300"}}, {"type": "box", "y": [82.283, 76.339, 85.363, 82.785, 89.034, 83.724, 80.518, 84.63, 98.858, 80.644, 80.565, 79.067, 77.436, 88.452], "name": "Wednesday", "marker": {"color": "875692"}}, {"type": "box", "y": [76.081, 77.549, 80.113, 81.628, 81.789, 76.882, 83.289, 84.568, 76.44, 74.745, 108.394, 85.105], "name": "Thursday", "marker": {"color": "F38400"}}, {"type": "box", "y": [100.581, 80.436, 84.307, 76.225, 74.434, 80.485, 79.166, 159.435, 86.904, 79.865, 80.689, 85.669, 96.182], "name": "Friday", "marker": {"color": "A1CAF1"}}, {"type": "box", "y": [88.725, 98.624, 74.81, 76.338, 72.28, 73.939, 73.661], "name": "Saturday", "marker": {"color": "BE0032"}}, {"type": "box", "y": [110.121, 87.306, 75.865, 78.731, 76.899, 79.009], "name": "Sunday", "marker": {"color": "C2B280"}}], {"title": "Ping latency(speedtest) by day of the week for the device 7 over the last 2w", "xaxis": {"title": "weekday"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
by_weekday_by_device_p2=mean_max_median_by2(input_dataframe=ping_speedtest_dataframe,value1="PING", value2="PING",
                                          value3="PING",group_by_value="weekday", rename_columns=True)

# %%
device_number=7
subset=by_weekday_by_device_p2[by_weekday_by_device_p2["SK_PI"]==device_number]
combined_bar_plot_3traces(xvalues=subset["weekday"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(speedtest) by day of the week for the device "+str(device_number)+" over the last "+time_interval,
                         xtitle="day of the week",
                         stack=False)
# Out:
# <div id="8aeef46c-6222-4dd3-9a4f-3648787b316f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8aeef46c-6222-4dd3-9a4f-3648787b316f", [{"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [100.152, 220.42, 98.858, 108.394, 159.435, 98.624, 110.121], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [85.6153076923077, 96.38783333333332, 83.54985714285714, 82.21525, 89.56753846153846, 79.76814285714285, 84.65516666666666], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [82.149, 80.614, 82.53399999999999, 80.87049999999999, 80.689, 74.81, 78.87], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(speedtest) by day of the week for the device 7 over the last 2w", "xaxis": {"title": "day of the week"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
weekday="Tuesday"
subset=by_weekday_by_device_p2[by_weekday_by_device_p2["weekday"]==weekday]
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(speedtest) by day of the week for the day "+str(weekday)+" over the last "+time_interval,
                         stack=False)
# Out:
# <div id="dff151a9-95fa-4748-98fb-6f1058cf26be" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dff151a9-95fa-4748-98fb-6f1058cf26be", [{"type": "bar", "x": [3, 5, 7, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [6.461, 207.71, 220.42, 132.71, 189.704, 80.098, 39.646, 41.622, 83.342, 300.549, 86.081, 60.255], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 5, 7, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [6.341333333333332, 110.68499999999999, 96.38783333333332, 82.43666666666667, 131.994375, 75.41533333333332, 36.216833333333334, 39.02541666666667, 76.4295, 122.3306, 71.52245454545455, 51.167], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 5, 7, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [6.3445, 81.65100000000001, 80.614, 85.00649999999999, 117.50200000000001, 74.3175, 35.951499999999996, 40.4485, 74.72200000000001, 100.605, 69.548, 49.674], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(speedtest) by day of the week for the day Tuesday over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
ping_speedtest_dataframe["day_group"]="Weekday"
ping_speedtest_dataframe.loc[(ping_speedtest_dataframe["weekday"]=="Sunday")|(ping_speedtest_dataframe["weekday"]=="Saturday"),"day_group"]="Weekend"

# %%
device_number=7
subset=ping_speedtest_dataframe[ping_speedtest_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='PING',sort_value='day_group',
               title="Ping latency(speedtest) by day group for the device "+str(device_number)+" over the last "+time_interval,
               ytitle="Miliseconds")
# Out:
# <div id="7501d3cd-1fe9-4510-8ed1-37deb5b055d9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7501d3cd-1fe9-4510-8ed1-37deb5b055d9", [{"type": "box", "y": [95.855, 82.014, 94.528, 93.295, 83.451, 82.149, 79.523, 81.361, 80.353, 78.22, 79.434, 134.032, 82.283, 76.339, 85.363, 82.785, 89.034, 83.724, 80.518, 76.081, 77.549, 80.113, 81.628, 81.789, 76.882, 100.581, 80.436, 84.307, 76.225, 74.434, 80.485, 78.783, 80.396, 76.119, 76.493, 88.735, 81.029, 100.152, 82.277, 220.42, 80.875, 76.857, 79.567, 83.735, 84.63, 98.858, 80.644, 80.565, 79.067, 77.436, 88.452, 83.289, 84.568, 76.44, 74.745, 108.394, 85.105, 79.166, 159.435, 86.904, 79.865, 80.689, 85.669, 96.182], "name": "Weekday", "marker": {"color": "222222"}}, {"type": "box", "y": [88.725, 98.624, 74.81, 76.338, 72.28, 73.939, 73.661, 110.121, 87.306, 75.865, 78.731, 76.899, 79.009], "name": "Weekend", "marker": {"color": "F3C300"}}], {"title": "Ping latency(speedtest) by day group for the device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
by_group_by_device_p2 = mean_max_median_by2(input_dataframe=ping_speedtest_dataframe,value1="PING", value2="PING",
                                             value3="PING",group_by_value="day_group", rename_columns=True)

# %%
device_number=7
subset=by_group_by_device_p2[by_group_by_device_p2["SK_PI"]==device_number]
combined_bar_plot_3traces(xvalues=subset["day_group"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(speedtest) by day group for the device "+str(device_number)+" over the last "+time_interval,
                         xtitle="day_group",
                         stack=False)
# Out:
# <div id="ba0e2031-8f97-4e50-bfd2-830458e205c5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ba0e2031-8f97-4e50-bfd2-830458e205c5", [{"type": "bar", "x": ["Weekday", "Weekend"], "y": [220.42, 110.121], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [87.34862500000001, 82.0236923076923], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [81.4945, 76.899], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(speedtest) by day group for the device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
day_group="Weekday"
subset=by_group_by_device_p2[by_group_by_device_p2["day_group"]==day_group]
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Ping latency(speedtest) by device for "+day_group+"s over the last "+time_interval,
                         stack=False)
# Out:
# <div id="28fff425-0ce5-4986-999b-e151f3ec7ef1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("28fff425-0ce5-4986-999b-e151f3ec7ef1", [{"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [33.228, 254.134, 220.42, 54.153, 143.842, 323.922, 82.933, 130.586, 46.69, 85.754, 1141.501, 86.081, 68.659], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [7.265953124999999, 101.11278124999998, 87.34862500000001, 22.50227272727273, 84.89226562500001, 133.52257142857147, 74.56801562499999, 45.090031249999996, 38.341301587301594, 76.53729687500001, 188.3098644067796, 70.12075806451612, 50.92214516129034], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [6.3815, 81.275, 81.4945, 20.081, 84.658, 119.528, 73.8745, 39.3955, 39.764, 77.22399999999999, 103.363, 69.6945, 49.706], "marker": {"color": "F38400"}, "name": "Median"}], {"title": "Ping latency(speedtest) by device for Weekdays over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Miliseconds"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## Upload speed

# %%
query_upload = "SELECT * FROM SPEEDTEST_UPLOAD WHERE PROVIDER!='iperf' AND time >= now()-"+time_interval+" AND UPLOAD!=0;"
upload_speedtest_dataframe = get_dataframe_from_influxdb(client_df=client_df,query_influx=query_upload,table_name='SPEEDTEST_UPLOAD')

# %%
upload_speedtest_dataframe["weekday"]=upload_speedtest_dataframe["time"].dt.weekday_name
upload_speedtest_dataframe["weekday"] = pd.Categorical(upload_speedtest_dataframe["weekday"], ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])

# %%
device_number=7
subset=upload_speedtest_dataframe[upload_speedtest_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='UPLOAD',sort_value='weekday',
               title="Upload speed by day of the week for the device "+str(device_number)+" over the last "+time_interval,
               ytitle="Mbps",uploadline=True, weekdays=True)
# Out:
# <div id="a16ece5e-acf6-4fa7-9c1d-7a29a5f0d309" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a16ece5e-acf6-4fa7-9c1d-7a29a5f0d309", [{"type": "box", "y": [5.58, 6.61, 10.61, 6.81, 6.17, 4.42, 9.59, 3.62, 10.88, 9.08, 6.35, 1.7, 10.38], "name": "Monday", "marker": {"color": "222222"}}, {"type": "box", "y": [7.27, 5.92, 12.24, 9.7, 9.09, 4.83, 8.86, 4.82, 10.74, 4.49, 7.09, 6.3], "name": "Tuesday", "marker": {"color": "F3C300"}}, {"type": "box", "y": [6.71, 7.23, 11.77, 9.65, 9.7, 11.87, 11.91, 7.41, 3.91, 12.28, 13.36, 9.86, 9.8, 8.46], "name": "Wednesday", "marker": {"color": "875692"}}, {"type": "box", "y": [8.29, 8.74, 12.17, 9.03, 10.02, 10.66, 3.4, 6.5, 8.53, 12.36, 7.89, 7.57], "name": "Thursday", "marker": {"color": "F38400"}}, {"type": "box", "y": [4.54, 6.84, 10.75, 12.97, 9.64, 9.75, 11.95, 3.54, 12.28, 15.04, 6.89, 6.19, 7.38], "name": "Friday", "marker": {"color": "A1CAF1"}}, {"type": "box", "y": [9.5, 10.24, 9.74, 12.06, 10.34, 9.03, 8.76], "name": "Saturday", "marker": {"color": "BE0032"}}, {"type": "box", "y": [6.7, 6.15, 7.99, 11.87, 8.45, 8.45], "name": "Sunday", "marker": {"color": "C2B280"}}, {"type": "scatter", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [10, 10, 10, 10, 10, 10, 10], "mode": "markers", "marker": {"color": "red"}, "name": "10Mps"}], {"title": "Upload speed by day of the week for the device 7 over the last 2w", "xaxis": {"title": "weekday"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
by_weekday_by_device_u=mean_max_median_by2(input_dataframe=upload_speedtest_dataframe,value1="UPLOAD", value2="UPLOAD",
                                          value3="UPLOAD",group_by_value="weekday", rename_columns=True)

# %%
device_number=7
subset=by_weekday_by_device_u[by_weekday_by_device_u["SK_PI"]==device_number]
uploadline=go.Scatter(x=subset["weekday"],y=[10] * len(subset["weekday"]), mode='markers',marker=dict(color='red'), name='10Mps')
combined_bar_plot_3traces(xvalues=subset["weekday"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Upload speed by day of the week for the device "+str(device_number)+" over the last "+time_interval,
                         xtitle="weekday",
                         ytitle="Mbps",
                         line=uploadline,
                         stack=False)
# Out:
# <div id="9d723f26-9da4-477c-8185-98b4343f4248" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9d723f26-9da4-477c-8185-98b4343f4248", [{"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [10.88, 12.24, 13.36, 12.36, 15.04, 12.06, 11.87], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [7.061538461538461, 7.6125, 9.565714285714284, 8.763333333333334, 9.05846153846154, 9.952857142857145, 8.268333333333333], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [6.61, 7.18, 9.75, 8.635, 9.64, 9.74, 8.219999999999999], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [10, 10, 10, 10, 10, 10, 10], "mode": "markers", "marker": {"color": "red"}, "name": "10Mps"}], {"title": "Upload speed by day of the week for the device 7 over the last 2w", "xaxis": {"title": "weekday"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
weekday="Friday"
subset=by_weekday_by_device_u[by_weekday_by_device_u["weekday"]==weekday]
uploadline=go.Scatter(x=subset["SK_PI"],y=[10] * len(subset["SK_PI"]), mode='markers',marker=dict(color='red'), name='10Mps')
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Upload speed by day of the week for the day "+str(weekday)+" over the last "+time_interval,
                         ytitle="Mbps",
                         line=uploadline,
                         stack=False)
# Out:
# <div id="bcb6cbd3-fde1-4fad-b354-b60ec4c16de1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bcb6cbd3-fde1-4fad-b354-b60ec4c16de1", [{"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [128.09, 0.61, 15.04, 120.97, 57.02, 4.03, 59.66, 9.06, 140.79, 47.49, 4.01, 49.77, 9.95], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [125.59538461538462, 0.51, 9.05846153846154, 90.76833333333333, 51.11538461538461, 3.2840000000000003, 56.17076923076923, 6.906153846153846, 120.05076923076922, 43.73615384615384, 3.4483333333333337, 46.86000000000001, 9.546153846153846], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [126.01, 0.5, 9.64, 89.975, 55.31, 3.43, 56.22, 6.9, 121.06, 44.04, 3.495, 47.09, 9.55], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "mode": "markers", "marker": {"color": "red"}, "name": "10Mps"}], {"title": "Upload speed by day of the week for the day Friday over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
upload_speedtest_dataframe["day_group"]="Weekday"
upload_speedtest_dataframe.loc[(upload_speedtest_dataframe["weekday"]=="Sunday")|(upload_speedtest_dataframe["weekday"]=="Saturday"),"day_group"]="Weekend"

# %%
device_number=7
subset=upload_speedtest_dataframe[upload_speedtest_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='UPLOAD',sort_value='day_group',
               title="Upload speed by day group for device "+str(device_number)+" over the last "+time_interval,
               ytitle="Mbps",uploadline=True)
# Out:
# <div id="df9d903e-8172-4d82-9f53-47faf6afbef5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("df9d903e-8172-4d82-9f53-47faf6afbef5", [{"type": "box", "y": [5.58, 6.61, 10.61, 6.81, 6.17, 4.42, 7.27, 5.92, 12.24, 9.7, 9.09, 4.83, 6.71, 7.23, 11.77, 9.65, 9.7, 11.87, 11.91, 8.29, 8.74, 12.17, 9.03, 10.02, 10.66, 4.54, 6.84, 10.75, 12.97, 9.64, 9.75, 9.59, 3.62, 10.88, 9.08, 6.35, 1.7, 10.38, 8.86, 4.82, 10.74, 4.49, 7.09, 6.3, 7.41, 3.91, 12.28, 13.36, 9.86, 9.8, 8.46, 3.4, 6.5, 8.53, 12.36, 7.89, 7.57, 11.95, 3.54, 12.28, 15.04, 6.89, 6.19, 7.38], "name": "Weekday", "marker": {"color": "222222"}}, {"type": "box", "y": [9.5, 10.24, 9.74, 12.06, 10.34, 9.03, 8.76, 6.7, 6.15, 7.99, 11.87, 8.45, 8.45], "name": "Weekend", "marker": {"color": "F3C300"}}, {"type": "scatter", "x": ["Weekday", "Weekend"], "y": [10, 10], "mode": "markers", "marker": {"color": "red"}, "name": "10Mps"}], {"title": "Upload speed by day group for device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
by_group_by_device_u = mean_max_median_by2(input_dataframe=upload_speedtest_dataframe,value1="UPLOAD", value2="UPLOAD",
                                             value3="UPLOAD",group_by_value="day_group", rename_columns=True)

# %%
device_number=7
subset=by_group_by_device_u[by_group_by_device_u["SK_PI"]==device_number]
uploadline=go.Scatter(x=subset["day_group"],y=[10] * len(subset["day_group"]), mode='markers',marker=dict(color='red'), name='10Mps')
combined_bar_plot_3traces(xvalues=subset["day_group"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Upload speed by day group for the device "+str(device_number)+" over the last "+time_interval,
                         ytitle="Mbps",
                         xtitle="day_group",
                         line=uploadline,
                         stack=False)
# Out:
# <div id="e3fa05f6-834c-4c90-80dd-0cc93c10ecde" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e3fa05f6-834c-4c90-80dd-0cc93c10ecde", [{"type": "bar", "x": ["Weekday", "Weekend"], "y": [15.04, 12.06], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [8.43734375, 9.175384615384617], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [8.635, 9.03], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": ["Weekday", "Weekend"], "y": [10, 10], "mode": "markers", "marker": {"color": "red"}, "name": "10Mps"}], {"title": "Upload speed by day group for the device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
day_group="Weekend"
subset=by_group_by_device_u[by_group_by_device_u["day_group"]==day_group]
uploadline=go.Scatter(x=subset["SK_PI"],y=[10] * len(subset["SK_PI"]), mode='markers',marker=dict(color='red'), name='10Mps')
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Upload speed by device for "+day_group+"s over the last "+time_interval,
                         ytitle="Mbps",
                         line=uploadline,
                         stack=False)
# Out:
# <div id="19f5eb48-2c21-4e19-b101-d1c1c63770dc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("19f5eb48-2c21-4e19-b101-d1c1c63770dc", [{"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [128.68, 0.54, 12.06, 127.3, 60.17, 4.09, 59.84, 10.19, 145.73, 47.91, 4.02, 49.54, 10.29], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [126.97923076923078, 0.5084615384615385, 9.175384615384617, 96.94307692307692, 48.45230769230769, 3.659166666666667, 53.77230769230769, 8.396153846153847, 123.35538461538462, 43.73076923076922, 3.8400000000000007, 45.8123076923077, 9.587692307692306], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [127.56, 0.52, 9.03, 90.53, 52.4, 3.8449999999999998, 54.75, 8.71, 132.71, 43.72, 3.85, 47.46, 9.54], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10], "mode": "markers", "marker": {"color": "red"}, "name": "10Mps"}], {"title": "Upload speed by device for Weekends over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ## Download speed

# %%
query_download = "SELECT * FROM SPEEDTEST_DOWNLOAD WHERE PROVIDER!='iperf' AND time >= now()-"+time_interval+" AND DOWNLOAD!=0;"
download_speedtest_dataframe = get_dataframe_from_influxdb(client_df=client_df,query_influx=query_download,table_name='SPEEDTEST_DOWNLOAD')

# %%
download_speedtest_dataframe["weekday"]=download_speedtest_dataframe["time"].dt.weekday_name
upload_speedtest_dataframe["weekday"] = pd.Categorical(upload_speedtest_dataframe["weekday"], ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])

# %%
device_number=7
subset=download_speedtest_dataframe[download_speedtest_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='DOWNLOAD',sort_value='weekday',
               title="Download speed by day of the week for the device "+str(device_number)+" over the last "+time_interval,
               ytitle="Mbps",downloadline=True, weekdays=True)
# Out:
# <div id="05d9ce5d-f98d-44a2-b44a-a5e1afbd6dca" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("05d9ce5d-f98d-44a2-b44a-a5e1afbd6dca", [{"type": "box", "y": [9.46, 10.02, 12.09, 6.36, 11.25, 7.81, 11.62, 6.49, 12.03, 12.41, 8.51, 6.91, 10.76], "name": "Monday", "marker": {"color": "222222"}}, {"type": "box", "y": [9.13, 13.26, 13.99, 9.86, 10.46, 8.08, 13.11, 5.7, 14.81, 10.59, 8.37, 9.46], "name": "Tuesday", "marker": {"color": "F3C300"}}, {"type": "box", "y": [9.01, 10.21, 14.23, 14.58, 8.99, 12.46, 13.24, 10.52, 8.55, 13.89, 14.12, 13.85, 10.39, 12.11], "name": "Wednesday", "marker": {"color": "875692"}}, {"type": "box", "y": [8.99, 11.34, 13.53, 12.0, 12.63, 11.44, 6.36, 12.18, 12.59, 15.93, 7.16, 9.92], "name": "Thursday", "marker": {"color": "F38400"}}, {"type": "box", "y": [11.59, 11.66, 15.05, 15.14, 8.66, 12.71, 13.01, 6.42, 13.13, 14.51, 13.96, 10.5, 14.33], "name": "Friday", "marker": {"color": "A1CAF1"}}, {"type": "box", "y": [10.31, 11.41, 13.65, 13.54, 12.92, 11.8, 11.18], "name": "Saturday", "marker": {"color": "BE0032"}}, {"type": "box", "y": [10.27, 8.59, 13.88, 14.66, 13.99, 13.26], "name": "Sunday", "marker": {"color": "C2B280"}}, {"type": "scatter", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": [50, 50, 50, 50, 50, 50, 50], "mode": "markers", "marker": {"color": "red"}, "name": "50Mps"}], {"title": "Download speed by day of the week for the device 7 over the last 2w", "xaxis": {"title": "weekday"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
by_weekday_by_device_d=mean_max_median_by2(input_dataframe=download_speedtest_dataframe,value1="DOWNLOAD", value2="DOWNLOAD",
                                          value3="DOWNLOAD",group_by_value="weekday", rename_columns=True)

# %%
device_number=7
subset=by_weekday_by_device_d[by_weekday_by_device_d["SK_PI"]==device_number]
downloadline=go.Scatter(x=subset["weekday"],y=[50] * len(subset["weekday"]), mode='markers',marker=dict(color='red'), name='50Mps')
combined_bar_plot_3traces(xvalues=subset["weekday"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Download speed by day of the week for the device "+str(device_number)+" over the last "+time_interval,
                         xtitle="hour",
                         ytitle="Mbps",
                         line=downloadline,
                         stack=False)
# Out:
# <div id="50ae4c32-8664-447d-9fe8-f9b5733d74ac" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("50ae4c32-8664-447d-9fe8-f9b5733d74ac", [{"type": "bar", "x": ["Friday", "Monday", "Saturday", "Sunday", "Thursday", "Tuesday", "Wednesday"], "y": [15.14, 12.41, 13.65, 14.66, 15.93, 14.81, 14.58], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Friday", "Monday", "Saturday", "Sunday", "Thursday", "Tuesday", "Wednesday"], "y": [12.35923076923077, 9.670769230769231, 12.115714285714287, 12.441666666666668, 11.1725, 10.568333333333335, 11.867857142857142], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Friday", "Monday", "Saturday", "Sunday", "Thursday", "Tuesday", "Wednesday"], "y": [13.01, 10.02, 11.8, 13.57, 11.719999999999999, 10.16, 12.285], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": ["Friday", "Monday", "Saturday", "Sunday", "Thursday", "Tuesday", "Wednesday"], "y": [50, 50, 50, 50, 50, 50, 50], "mode": "markers", "marker": {"color": "red"}, "name": "50Mps"}], {"title": "Download speed by day of the week for the device 7 over the last 2w", "xaxis": {"title": "hour"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
weekday="Sunday"
subset=by_weekday_by_device_d[by_weekday_by_device_d["weekday"]==weekday]
downloadline=go.Scatter(x=subset["SK_PI"],y=[50] * len(subset["SK_PI"]), mode='markers',marker=dict(color='red'), name='50Mps')
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Download speed by day of the week for the day "+weekday+" over the last "+time_interval,
                         ytitle="Mbps",
                         line=downloadline,
                         stack=False)
# Out:
# <div id="16ed71d6-f717-4014-bdbe-c458993ca1fa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16ed71d6-f717-4014-bdbe-c458993ca1fa", [{"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [185.74, 6.6, 14.66, 120.55, 46.53, 5.69, 30.9, 18.19, 163.14, 23.25, 6.16, 41.44, 9.52], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [183.39999999999998, 6.0633333333333335, 12.441666666666668, 100.28000000000002, 41.34166666666667, 3.4483333333333337, 27.78666666666666, 16.465, 95.03166666666668, 18.25166666666667, 6.02, 39.37333333333333, 9.41], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [183.91, 6.47, 13.57, 91.025, 39.63, 3.1550000000000002, 28.305, 17.015, 89.69, 17.215, 6.0, 40.61, 9.440000000000001], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50], "mode": "markers", "marker": {"color": "red"}, "name": "50Mps"}], {"title": "Download speed by day of the week for the day Sunday over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
download_speedtest_dataframe["day_group"]="Weekday"
download_speedtest_dataframe.loc[(download_speedtest_dataframe["weekday"]=="Sunday")|(download_speedtest_dataframe["weekday"]=="Saturday"),"day_group"]="Weekend"

# %%
device_number=7
subset=download_speedtest_dataframe[download_speedtest_dataframe["SK_PI"]==device_number]
simple_boxplot(dataframe=subset,plot_value='DOWNLOAD',sort_value='day_group',
               title="Download speed by day group for device "+str(device_number)+" over the last "+time_interval,
               ytitle="Mbps",downloadline=True)
# Out:
# <div id="b445d8f1-377e-4cc0-a16a-b34b342c695b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b445d8f1-377e-4cc0-a16a-b34b342c695b", [{"type": "box", "y": [9.46, 10.02, 12.09, 6.36, 11.25, 7.81, 9.13, 13.26, 13.99, 9.86, 10.46, 8.08, 9.01, 10.21, 14.23, 14.58, 8.99, 12.46, 13.24, 8.99, 11.34, 13.53, 12.0, 12.63, 11.44, 11.59, 11.66, 15.05, 15.14, 8.66, 12.71, 11.62, 6.49, 12.03, 12.41, 8.51, 6.91, 10.76, 13.11, 5.7, 14.81, 10.59, 8.37, 9.46, 10.52, 8.55, 13.89, 14.12, 13.85, 10.39, 12.11, 6.36, 12.18, 12.59, 15.93, 7.16, 9.92, 13.01, 6.42, 13.13, 14.51, 13.96, 10.5, 14.33], "name": "Weekday", "marker": {"color": "222222"}}, {"type": "box", "y": [10.31, 11.41, 13.65, 13.54, 12.92, 11.8, 11.18, 10.27, 8.59, 13.88, 14.66, 13.99, 13.26], "name": "Weekend", "marker": {"color": "F3C300"}}, {"type": "scatter", "x": ["Weekday", "Weekend"], "y": [50, 50], "mode": "markers", "marker": {"color": "red"}, "name": "50Mps"}], {"title": "Download speed by day group for device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
by_group_by_device_d = mean_max_median_by2(input_dataframe=download_speedtest_dataframe,value1="DOWNLOAD", value2="DOWNLOAD",
                                             value3="DOWNLOAD",group_by_value="day_group", rename_columns=True)

# %%
device_number=7
subset=by_group_by_device_d[by_group_by_device_d["SK_PI"]==device_number]
downloadline=go.Scatter(x=subset["day_group"],y=[50] * len(subset["day_group"]), mode='markers',marker=dict(color='red'), name='50Mps')
combined_bar_plot_3traces(xvalues=subset["day_group"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Download speed by day group for device "+str(device_number)+" over the last "+time_interval,
                         ytitle="Mbps",
                         xtitle="day_group",
                         line=downloadline,
                         stack=False)
# Out:
# <div id="556a86c5-0d3a-4554-b36d-2eed80f49082" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("556a86c5-0d3a-4554-b36d-2eed80f49082", [{"type": "bar", "x": ["Weekday", "Weekend"], "y": [15.93, 14.66], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [11.14734375, 12.266153846153847], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": ["Weekday", "Weekend"], "y": [11.515, 12.92], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": ["Weekday", "Weekend"], "y": [50, 50], "mode": "markers", "marker": {"color": "red"}, "name": "50Mps"}], {"title": "Download speed by day group for device 7 over the last 2w", "xaxis": {"title": "day_group"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
day_group="Weekend"
subset=by_group_by_device_d[by_group_by_device_d["day_group"]==day_group]
downloadline=go.Scatter(x=subset["SK_PI"],y=[50] * len(subset["SK_PI"]), mode='markers',marker=dict(color='red'), name='50Mps')
combined_bar_plot_3traces(xvalues=subset["SK_PI"],
                         yvalues1=subset["max"],
                         yvalues2=subset["mean"],
                         yvalues3=subset["median"],
                         name1="Max",
                         name2="Mean",
                         name3="Median",
                         title="Download speed by device for "+day_group+"s over the last "+time_interval,
                         ytitle="Mbps",
                         line=downloadline,
                         stack=False)
# Out:
# <div id="32cbf7ad-c41e-4aee-be0b-cf56f4897de2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("32cbf7ad-c41e-4aee-be0b-cf56f4897de2", [{"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [185.74, 6.66, 14.66, 123.21, 46.53, 6.46, 30.9, 18.19, 163.3, 23.25, 6.27, 42.2, 9.52], "marker": {"color": "F3C300"}, "name": "Max"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [183.0407692307692, 6.161538461538461, 12.266153846153847, 102.26384615384615, 40.77307692307692, 4.214166666666666, 27.09538461538462, 16.26615384615385, 80.52999999999999, 18.28923076923077, 5.987272727272727, 37.85615384615385, 9.35923076923077], "marker": {"color": "875692"}, "name": "Mean"}, {"type": "bar", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [182.89, 6.5, 12.92, 91.27, 42.49, 4.05, 27.39, 16.68, 43.57, 17.92, 6.04, 40.25, 9.39], "marker": {"color": "F38400"}, "name": "Median"}, {"type": "scatter", "x": [3, 5, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18], "y": [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50], "mode": "markers", "marker": {"color": "red"}, "name": "50Mps"}], {"title": "Download speed by device for Weekends over the last 2w", "xaxis": {"title": "Device Number"}, "yaxis": {"title": "Mbps"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
